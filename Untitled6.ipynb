# %%
from sentimenttime import senti_utils

# %%
corpus_ls = senti_utils.file2segs('./books/cdickens_chirstmascarol.txt')
# Out:
# IN file2str()
# Finally!

# %%
from sentimenttime import senti_lexicon

# %%
corpus_sa_ls = senti_lexicon.corpus2sa_ls(corpus_ls)
# Out:
# just read in 10748 words into syuzhet_dt of type <class 'dict'>
# exit get_sa_lex() with 10748 entries in syuzhet_dt
# in corpus2sa_ls processing sent #0: A CHRISTMAS CAROL In Prose BEING A GHOST STORY OF CHRISTMAS STAVE ONE MARLEY'S GHOST Marley was dead, to begin with.
# in sent2lex with text of type <class 'str'>, text = A CHRISTMAS CAROL In Prose BEING A GHOST STORY OF CHRISTMAS STAVE ONE MARLEY'S GHOST Marley was dead, to begin with.
# In sent2lex_sa with text= a christmas carol in prose being a ghost story of christmas stave one marleys ghost marley was dead to begin with
# looking up the word: a
# looking up the word: christmas
# looking up the word: carol
# looking up the word: in
# looking up the word: prose
# looking up the word: being
# looking up the word: a
# looking up the word: ghost
# ghost has a sentiment value of -0.6
# looking up the word: story
# looking up the word: of
# looking up the word: christmas
# looking up the word: stave
# looking up the word: one
# ...

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-a0d2faabd9e9> in <module>
# ----> 1 import matplotlib.pyplot as plt
#
# ~\miniconda3\lib\site-packages\matplotlib\pyplot.py in <module>
#      34 from cycler import cycler
#      35 import matplotlib
# ---> 36 import matplotlib.colorbar
#      37 import matplotlib.image
#      38 from matplotlib import rcsetup, style
#
# ~\miniconda3\lib\site-packages\matplotlib\colorbar.py in <module>
#      42 import matplotlib.collections as collections
#      43 import matplotlib.colors as colors
# ---> 44 import matplotlib.contour as contour
#      45 import matplotlib.cm as cm
#      46 import matplotlib.gridspec as gridspec
#
# ~\miniconda3\lib\site-packages\matplotlib\contour.py in <module>
#      15 import matplotlib.collections as mcoll
#      16 import matplotlib.font_manager as font_manager
# ...
